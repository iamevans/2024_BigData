# %% [markdown]
# ## 30900_evans_0318_1

# %% [markdown]
# ![image.png](attachment:0e343727-9bd5-47ef-9606-5d150b5ba243.png)

# %%
# 세 정수를 입력받아 최댓값 구하기

print('세 정수의 최댓값을 구합니다.')

a = int(input('정수 a의 값을 입력하세요.: '))
b = int(input('정수 b의 값을 입력하세요.: '))
c = int(input('정수 c의 값을 입력하세요.: '))

# 최대값을 구하는 알고리즘
max = a
if b > max : max = b
if c > max : max = c

print(f'최대값은 {max}입니다.')
# Out:
# 세 정수의 최댓값을 구합니다.
# 정수 a의 값을 입력하세요.:  1
# 정수 b의 값을 입력하세요.:  23
# 정수 c의 값을 입력하세요.:  2
# 최대값은 23입니다.

# %% [markdown]
# ![image.png](attachment:0e3a8831-ed50-40ee-b610-cc634940c25b.png)

# %% [markdown]
# ![image.png](attachment:39583d39-54ef-4b3e-b0cc-a924540017d4.png)

# %%
# 입력 받은 정수의 부호(양수, 음수, 0)출력하기

n = int(input('정수를 입력하세요.: '))

if n > 0 :
    print('이 수는 양수입니다.')
elif n < 0 :
    print('이 수는 음수입니다.')
else :
    print('이 수는 0입니다.')
# Out:
# 정수를 입력하세요.:  0
# 이 수는 0입니다.

# %% [markdown]
# ![image.png](attachment:cb0887f3-6dc0-4665-b3b4-7fa3a539a3f6.png)

# %% [markdown]
# ![image.png](attachment:6f98227f-5203-48c0-80ee-75f131b2525d.png)

# %%
# while문 이용
# 1부터 n까지 정수의 합 구하기

print('1부터 n까지 정수의 합을 구합니다.')
n = int(input('n값을 입력하세요.: '))

sum = 0 #초기화
i = 1

while i <= n :
    sum += i #sum = sum + i
    i += 1 #i = i + 1

#출력
print(f'1부터 {n}까지 정수의 합은 {sum}입니다.')
# Out:
# 1부터 n까지 정수의 합을 구합니다.
# n값을 입력하세요.:  10
# 1부터 10까지 정수의 합은 55입니다.
